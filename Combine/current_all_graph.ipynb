# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('current_max_combine.csv')

x = df['test']
y0 = df['max0']
y1 = df['max1']
y5 = df['max5']
y10 = df['max10']
y11 = df['max11']
y12 = df['max12']
y13 = df['max13']
y15 = df['max15']
y20 = df['max20']
y24 = df['max24']
y26 = df['max26']
y27 = df['max27']
y28 = df['max28']

plt.figure(figsize=(8,6))
plt.title("Max value Against Sample Rate")
plt.xlabel("Sample Rate", fontsize=12)
plt.ylabel("Current(Mean Value) A", fontsize=12)

plt.plot(x,y0,label='Healthy Condition')
plt.plot(x,y1,label='Test1')
plt.plot(x,y5,label='Test5')
plt.plot(x,y10,label='Test10')
plt.plot(x,y11,label='Test11')
plt.plot(x,y12,label='Test12')
plt.plot(x,y13,label='Test13')
plt.plot(x,y15,label='Test15')
plt.plot(x,y20,label='Test20')
plt.plot(x,y24,label='Test24')
plt.plot(x,y26,label='Test26')
plt.plot(x,y27,label='Test27')
# plt.plot(x,y28,label='Test28')

plt.ylim(6,8.5)

plt.legend()
plt.show()
