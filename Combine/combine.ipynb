# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('combine_file.csv')

# %%
df = pd.DataFrame(df)
df.head()
# Out:
#    Part     F_mean  F_max  F_min      F_rms  F_std_dev  F_skewness  \
# 0     1  72.398305  531.0   51.0  85.099194  44.916093    9.404405
# 1     2  63.025424   77.0   42.0  63.370781   6.635133   -0.442525
# 2     3  62.398305   77.0   42.0  62.776777   6.912320   -0.958236
# 3     4  62.500000   77.0   51.0  62.744370   5.555855   -0.206997
# 4     5  61.152542   77.0   42.0  61.641665   7.782983   -0.572240
#
#    F_crest_factor  F_form_factor    I_mean  ...  I_form_factor     P_mean  \
# 0        6.239777       1.175431  8.096805  ...       1.000031  73.742754
# 1        1.215071       1.005480  8.046263  ...       1.000021  74.194203
# 2        1.226568       1.006065  7.994980  ...       1.000014  74.670290
# 3        1.227202       1.003910  7.971940  ...       1.000016  76.463043
# 4        1.249155       1.007998  7.959305  ...       1.000010  72.358696
#
#    P_max   P_min      P_rms   P_std_dev   P_skewness   P_crest_factor  \
# ...

# %%
df.shape
# Out:
# (30000, 26)

# %%
df.describe()
# Out:
#                Part        F_mean         F_max         F_min         F_rms  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     500.447800     40.318339     49.469639     33.284011     40.592287
# std      288.596145     15.230923     28.240491     14.206236     15.201806
# min        1.000000     11.597938     17.000000      8.000000     11.925456
# 25%      250.750000     28.030612     34.650000     18.900000     28.174204
# 50%      500.500000     45.960000     51.000000     42.000000     46.176617
# 75%      750.250000     50.307692     60.000000     42.000000     50.402318
# max     1000.000000     73.093220    531.000000     60.000000     85.605075
#
#           F_std_dev    F_skewness  F_crest_factor  F_form_factor  \
# count  30000.000000  30000.000000    30000.000000   30000.000000
# mean       4.097777     -0.026762        1.229211       1.009909
# std        2.161530      1.618833        0.409490       0.015861
# ...

# %%
df.isnull().sum()
# Out:
# Part               0
# F_mean             0
# F_max              0
# F_min              0
# F_rms              0
# F_std_dev          0
# F_skewness         0
# F_crest_factor     0
# F_form_factor      0
# I_mean             0
# I_max              0
# I_min              0
# I_rms              0
# I_std_dev          0
# I_skewness         0
# I_crest_factor     0
# I_form_factor      0
#  P_mean            0
# P_max              0
#  P_min             0
#  P_rms             0
#  P_std_dev         0
#  P_skewness        0
#  P_crest_factor    0
#  P_form_factor     0
# fault_type         0
# dtype: int64

# %%
# Simulate data (7 features, replace with actual data if available)
np.random.seed(42)
data = np.random.rand(20, 8) * 10  # 20 rows, 7 columns of sensor readings
columns =  ['mean', 'max', 'min', 'Rms','std_dev', 'skewness','crest_factor', 'form_factor']
df = pd.DataFrame(data, columns=columns)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)

# Customizing the heatmap
plt.title("Feature Correlation Heatmap Including combine Fault", fontsize=16)
# plt.xlabel("Features", fontsize=12)
# plt.ylabel("Features", fontsize=12)
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.yticks(rotation=0)   # Keep y-axis labels horizontal
plt.tight_layout()

# Display the heatmap
plt.show()

# %%
 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# importing the models
 
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier  # Import XGBoost

# %%
y = df['fault_type']  # Assign the 'fault_type' column to y
x = df.iloc[:, :-1]   # Exclude the last column and assign the remaining DataFrame to x

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.20, random_state=42)

# %%
 # List of models
models_list = [
    
    SVC(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=0),
    XGBClassifier(use_label_encoder=False, eval_metric='logloss')  # Add XGBoost
]

# %%
model_hyperparameters = {
    'svc_hyperparameters': {
        'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
        'C': [1, 5, 10, 20],
         
    },

    'KNN_hyperparameters': {
        'n_neighbors': [3, 5, 10, 20],
        
        'p': [1, 2],  # Distance metric: 1=Manhattan, 2=Euclidean
   
    },

    'random_forest_hyperparameters': {
        'n_estimators': [10, 20, 50, 100, 200],  # Number of trees
        'max_depth': [None, 10, 20, 30],  # Depth of the tree
        
        'criterion': ['gini', 'entropy']  # Function to measure the quality of a split
    },

    'xgboost_hyperparameters': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],  # Step size shrinkage
        'max_depth': [3, 6, 10],  # Maximum depth of a tree
        
    }
}

# %%
def ModelSelection(list_of_models, hyperparameters_dictionary):

  result = []

  i = 0

  for model in list_of_models:

    key = model_keys[i]

    params = hyperparameters_dictionary[key]

    i += 1

    print(model)
    print(params)
    print('---------------------------------')


    classifier = GridSearchCV(model, params, cv=5)

    # fitting the data to classifier
    # x_scaled = scaler.fit_transform(x)
    classifier.fit(X_train,y_train)

    result.append({
        'model used' : model,
        'highest score' : classifier.best_score_,
        'best hyperparameters' : classifier.best_params_
    })

  result_dataframe = pd.DataFrame(result, columns = ['model used','highest score','best hyperparameters'])

  return result_dataframe

# %%
model_keys = list(model_hyperparameters.keys())
print(model_keys)
# Out:
# ['svc_hyperparameters', 'KNN_hyperparameters', 'random_forest_hyperparameters', 'xgboost_hyperparameters']

# %%
results = ModelSelection(models_list, model_hyperparameters )
print(results)
# Out:
# SVC()
# {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'C': [1, 5, 10, 20]}
# ---------------------------------
# KNeighborsClassifier()
# {'n_neighbors': [3, 5, 10, 20], 'p': [1, 2]}
# ---------------------------------
# RandomForestClassifier(random_state=0)
# {'n_estimators': [10, 20, 50, 100, 200], 'max_depth': [None, 10, 20, 30], 'criterion': ['gini', 'entropy']}
# ---------------------------------
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=0,criterion='entropy',max_depth=None,n_estimators=10)

clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9948

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(16, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# average (optional): This parameter defines the type of averaging performed on the data. It can take several values:
#
#     'micro': Calculates metrics globally by counting the total true positives, false negatives, and false positives.
#     'macro': Calculates metrics for each label and finds their unweighted mean. This does not take label imbalance into account.
#     'weighted': Calculates metrics for each label and finds their average, weighted by support (the number of true instances for each label).
#     None: Returns the score for each class.

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Precision: 0.9949
# Recall: 0.9948
# F1 Score: 0.9948

# %%
xg = XGBClassifier(learning_rate = 0.2, max_depth = 3, n_estimators = 100)

# %%
xg.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xg_predict = xg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
precision = precision_score(y_test, xg_predict, average='weighted')
recall = recall_score(y_test, xg_predict, average='weighted')
f1 = f1_score(y_test, xg_predict, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
 
accuracy = accuracy_score(y_test, xg_predict)
print('accuracy', accuracy)
# Out:
# Precision: 0.9990
# Recall: 0.9990
# F1 Score: 0.9990
# accuracy 0.999

# %%
knn = KNeighborsClassifier(n_neighbors=10, p=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10, p=1)

# %%
knn_predict = knn.predict(X_test)

# %%
precision = precision_score(y_test, knn_predict, average='weighted')
recall = recall_score(y_test, knn_predict, average='weighted')
f1 = f1_score(y_test, knn_predict, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
 
accuracy = accuracy_score(y_test, knn_predict)
print('accuracy', accuracy)
# Out:
# Precision: 0.8179
# Recall: 0.7975
# F1 Score: 0.7975
# accuracy 0.7975

# %%
svc = SVC(C= 5 , kernel = 'linear')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(C=5, kernel='linear')

# %%
svc_predict = svc.predict(X_test)

# %%
precision = precision_score(y_test, svc_predict, average='weighted')
recall = recall_score(y_test, svc_predict, average='weighted')
f1 = f1_score(y_test, svc_predict, average='weighted')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
 
accuracy = accuracy_score(y_test, svc_predict)
print('accuracy', accuracy)
# Out:
# Precision: 0.9866
# Recall: 0.9855
# F1 Score: 0.9856
# accuracy 0.9855
