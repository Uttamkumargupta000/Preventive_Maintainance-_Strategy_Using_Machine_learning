# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Flow_Combine.csv')
df.head()
# Out:
#       F_mean  F_max  F_min      F_rms  F_std_dev  F_skewness  F_crest_factor  \
# 0  72.398305  531.0   51.0  85.099194  44.916093    9.404405        6.239777
# 1  63.025424   77.0   42.0  63.370781   6.635133   -0.442525        1.215071
# 2  62.398305   77.0   42.0  62.776777   6.912320   -0.958236        1.226568
# 3  62.500000   77.0   51.0  62.744370   5.555855   -0.206997        1.227202
# 4  61.152542   77.0   42.0  61.641665   7.782983   -0.572240        1.249155
#
#    F_form_factor
# 0       1.175431
# 1       1.005480
# 2       1.006065
# 3       1.003910
# 4       1.007998

# %%
df.isnull().sum()
# Out:
# F_mean            0
# F_max             0
# F_min             0
# F_rms             0
# F_std_dev         0
# F_skewness        0
# F_crest_factor    0
# F_form_factor     0
# dtype: int64

# %%
df.describe()
# Out:
#              F_mean         F_max         F_min         F_rms     F_std_dev  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      40.318339     49.469639     33.284011     40.592287      4.097777
# std       15.230923     28.240491     14.206236     15.201806      2.161530
# min       11.597938     17.000000      8.000000     11.925456      0.000000
# 25%       28.030612     34.650000     18.900000     28.174204      3.139683
# 50%       45.960000     51.000000     42.000000     46.176617      4.090554
# 75%       50.307692     60.000000     42.000000     50.402318      4.514651
# max       73.093220    531.000000     60.000000     85.605075     45.364866
#
#          F_skewness  F_crest_factor  F_form_factor
# count  30000.000000    30000.000000   30000.000000
# mean      -0.026762        1.229211       1.009909
# std        1.618833        0.409490       0.015861
# min      -10.198039        1.000000       1.000000
# ...

# %%
# Simulating a dataset (replace with actual data)
np.random.seed(42)
data = np.random.rand(20, 8) * 10  # 20 rows, 7 columns of sensor readings
columns =  ['mean', 'max', 'min', 'Rms','std_dev', 'skewness','crest_factor', 'form_factor']
df = pd.DataFrame(data, columns=columns)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)

# Customizing the heatmap
plt.title("Feature Correlation Heatmap Including Flow Value", fontsize=16)
# plt.xlabel("Features", fontsize=12)
# plt.ylabel("Features", fontsize=12)
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.yticks(rotation=0)   # Keep y-axis labels horizontal
plt.tight_layout()

# Display the heatmap
plt.show()
